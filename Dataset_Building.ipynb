# %% [markdown]
# <a href="https://colab.research.google.com/github/akritidu/Multi-label-Classification-in-the-Home-Improvement/blob/main/Dataset_Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
'/content/drive/MyDrive/Dataset/Stack_overflow_Home_improvement.json'
# Out:
# '/content/drive/MyDrive/Dataset/Stack_overflow_Home_improvement.json'

# %%
with open('/content/drive/MyDrive/Dataset/Stack_overflow_Home_improvement.json') as file:
    data = json.load(file)

# %%
data
# Out:
# {'https://diy.stackexchange.com/questions/204261/i-have-a-champion-120v-generator-i-want-to-use-it-to-plug-into-a-preinstalled-w': {'context': 'I have a new champion generator, 120volt at 20 to 30amp. The previous home owner had  the same unit but 240 volt. The home has a professionally installed system for power backup but has a 4 pin 240 volt outlet as per photo.\nMy question is, can I adapt my unit to the 240 volt system which I think is split phase because it also runs a 1.5HP well pump motor?\n\n',
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/56737/alaska-man',
#   'q_user_edit_time': '2020-09-26 18:23:53Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/123766/andy',
#   'q_user_owner_time': '2020-09-26 18:16:14Z',
#   'question': 'I have a Champion 120V generator, I want to use it to plug into a preinstalled/wired 240volt split phase outlet',
#   'related_questions': ['https://diy.stackexchange.com/questions/124266/i-have-a-120-240-dryer-from-canada-and-want-to-use-it-in-a-240v-country',
#    'https://diy.stackexchange.com/questions/153176/powering-220v-to-neutral-appliance-from-120v-split-phase',
#    'https://diy.stackexchange.com/questions/202610/is-it-possible-to-wire-a-240v-outlet-so-that-after-i-dont-need-240v-anymore-i-w'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/204189/can-i-run-conduit-containing-120v-wires-inside-larger-conduit-for-240v-wires': {'context': 'I was wondering if I could run 120v wires inside in a larger conduit that has higher voltage wires 240v, in a smaller piece of conduit?\nThe reason I ask is that I have a manufactured home and when they installed the 240v wiring coming from the meter it is run under the house in the crawlspace. It\'s not in conduit untill it enters the bottom of the electrical panel. When the water pump (120v) was installed they just ran it into the conduit with the 240v wiring.\nI know for certain you can\'t run low and high voltage in the same conduit, but I thought that if I ran a 1/2" conduit inside the 2" for the 120v that would rectify the violation.\n',
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/89023/jeff-wheeler',
#   'q_user_edit_time': '2020-09-25 13:41:17Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/123731/norman-sobieck',
#   'q_user_owner_time': '2020-09-25 10:05:54Z',
#   'question': 'Can I run conduit containing 120V wires inside larger conduit for 240V wires?',
#   'related_questions': ['https://diy.stackexchange.com/questions/47210/is-there-an-advantage-to-using-emt-over-plastic-flexible-conduit-for-low-voltage',
#    'https://diy.stackexchange.com/questions/63235/which-cable-conduit-should-i-use-to-run-a-new-240-volt-line-for-an-oven',
#    'https://diy.stackexchange.com/questions/88851/conduit-size-for-sub-panel-run',
#    'https://diy.stackexchange.com/questions/158582/can-i-run-thhn-for-separate-washer-and-dryer-circuits-through-the-same-conduit',
#    'https://diy.stackexchange.com/questions/176851/8-thhn-in-conduit-for-50-amp-circuits',
#    'https://diy.stackexchange.com/questions/176882/when-derating-for-wires-in-conduit-do-you-round-up-or-down',
#    'https://diy.stackexchange.com/questions/186428/does-a-new-manufactured-home-on-permanent-foundation-need-a-shutoff-within-30ft',
#    'https://diy.stackexchange.com/questions/192622/how-should-i-run-this-conduit-for-security-cameras-across-a-flat-roof',
#    'https://diy.stackexchange.com/questions/195093/can-i-replace-a-single-dedicated-20a-120v-receptacle-with-a-20a-240v-receptacle',
#    'https://diy.stackexchange.com/questions/203366/leave-extra-wire-in-conduit-for-future-expansion'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/conduit',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '1'},
#  'https://diy.stackexchange.com/questions/203504/30v-on-120-circuit-swapped-dishwashers-and-circuit-dropped-to-30v': {'context': "Situation: replaced dishwasher. Turned off the breaker first. The original DW is 100% fine, just doing an upgrade. I did not measure the voltage on the wires. New one - connect to existing wires, dedicated line, and nothing. I hot wired the new DW and it works connected to a different circuit. The dedicated run measures 30V on one meter, and 3V on another, and both meters read ~120V when plugged into an outlet. I stripped the wire back and did not get different result. Tomorrow I will pull open the panel and check for neutral, corroded buss, maybe a loose wire. Why would I get 30V when all i did was swap DWs' and wire is 20 year old ROMEX, 14 or 12 G. I am guessing I am at the breaker or in the panel issue? Thoughts? Bad luck? Thank you master experts!\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/123364/david-c-high',
#   'q_user_owner_time': '2020-09-16 01:52:36Z',
#   'question': '30V on 120 circuit - swapped dishwashers and circuit dropped to 30V',
#   'related_questions': ['https://diy.stackexchange.com/questions/110135/removing-wires-from-old-breaker',
#    'https://diy.stackexchange.com/questions/120882/ac-power-leaving-the-circuit-breaker-but-no-ac-power-to-ac-power-supply-line-in',
#    'https://diy.stackexchange.com/questions/123269/how-to-fix-electrical-system-that-feeds-a-studio-unit',
#    'https://diy.stackexchange.com/questions/149977/replacing-old-100-amp-electric-panel',
#    'https://diy.stackexchange.com/questions/159391/multi-wire-circuit-or-2-separate-120v-20a-dedicated-circuits',
#    'https://diy.stackexchange.com/questions/187006/moving-main-service-breaker-panel-lower-on-wall-exposes-feeder-wires-non-sheathe',
#    'https://diy.stackexchange.com/questions/200616/seeking-advice-on-how-to-rearrange-existing-breakers-and-add-2-circuits-includi'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '1'},
#  'https://diy.stackexchange.com/questions/203260/how-much-120-from-240-is-too-much': {'context': "I'm running a double circuit breaker from the house at 40amps with 8ga for both hots, the neutral and the ground out to my shed, which is roughly 20 feet. I've got a sub box in the shed where I want to run a 20a circuit at 240 for occasional equipment, and separate 120v circuits for outlets and lights. Since the neutral is unbroken and separate, what's the max 120v 20a circuits I can run safely only sharing the hot busses?  I wouldn't be using the 240 and 120 at the same time except for a couple chest freezers I will have out there, so too many tools won't be an issue.  Is 3 too much to ask?\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/123263/joshua-s',
#   'q_user_owner_time': '2020-09-13 11:51:13Z',
#   'question': 'How much 120 from 240 is too much?',
#   'related_questions': ['https://diy.stackexchange.com/questions/35658/can-i-install-a-subpanel-in-a-seperate-building-using-a-3-wire-connection-2-h',
#    'https://diy.stackexchange.com/questions/77451/can-i-have-a-120-volt-branch-off-a-120-240-volt-circuit',
#    'https://diy.stackexchange.com/questions/93945/can-i-safely-create-another-120v-outlet-using-the-fourth-neutral-wire-from-a-4-w',
#    'https://diy.stackexchange.com/questions/102853/odd-wiring-in-garage-split-240-breaker-into-two-120-circuits',
#    'https://diy.stackexchange.com/questions/108788/how-can-i-get-30-amps-120v-using-several-12awg-and-or-14awg-cables',
#    'https://diy.stackexchange.com/questions/139678/double-pole-240-volt-15-amp-gfci-circuit-breaker-to-create-two-15amp-120-circu',
#    'https://diy.stackexchange.com/questions/155899/does-anyone-know-how-to-split-the-240-v-wire-components-of-a-dryer-from-the-120',
#    'https://diy.stackexchange.com/questions/158582/can-i-run-thhn-for-separate-washer-and-dryer-circuits-through-the-same-conduit',
#    'https://diy.stackexchange.com/questions/183340/running-multiple-20a-circuits-to-a-shed',
#    'https://diy.stackexchange.com/questions/193746/can-i-use-2-runs-of-10-2-ubf-for-my-shed-90-from-house'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/shed',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/202610/is-it-possible-to-wire-a-240v-outlet-so-that-after-i-dont-need-240v-anymore-i-w': {'context': "I'm in the US.\nI will be installing a 240v outdoor outlet for an EVSE (electric car charger). However, in a few years I will have a garage built (elsewhere) and will move the EVSE to the garage, so won't need the 240v outlet anymore. At that point, I will instead use that outlet for my workshop and would like to have two 120v circuits: one for lights and a 120v air conditioner, one for power tools.\n[Edit: the workshop will be for power tools and the garage will be for parking/charging the car. They are not the same structure, the garage is unrelated to this question and will be far far away.]\nIs this possible with a single 240v cable? Alternatively, would it be possible to start with two 120v circuits of opposite phases, and wire them together to create 240v and then later go back to two 120v?\n\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '2020-09-07 00:35:12Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/24599/brentonstrine',
#   'q_user_owner_time': '2020-09-04 20:55:01Z',
#   'question': "Is it possible to wire a 240v outlet so that after I don't need 240v anymore I will have two 120v circuits?",
#   'related_questions': ['https://diy.stackexchange.com/questions/16438/what-are-my-options-for-installing-240v-receptacles-in-an-attached-garage',
#    'https://diy.stackexchange.com/questions/57982/how-can-i-convert-a-240v-dryer-outlet-to-two-branch-circuits',
#    'https://diy.stackexchange.com/questions/93945/can-i-safely-create-another-120v-outlet-using-the-fourth-neutral-wire-from-a-4-w',
#    'https://diy.stackexchange.com/questions/105090/240v-double-pole-breaker-for-two-120v-circuits',
#    'https://diy.stackexchange.com/questions/147448/buzzing-noise-coming-from-metal-conduit-when-circuit-under-load',
#    'https://diy.stackexchange.com/questions/172514/installing-a-240v-30-a-outlet-for-ev-charging',
#    'https://diy.stackexchange.com/questions/174288/future-proofing-for-240v-outlet',
#    'https://diy.stackexchange.com/questions/190493/running-240v-circuit-to-detached-garage',
#    'https://diy.stackexchange.com/questions/193147/can-a-120v-pool-timer-be-used-on-a-two-wire-240v-circuit',
#    'https://diy.stackexchange.com/questions/200935/a-b-switch-for-two-240v-connections-into-electrical-panel'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/240v',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '2'},
#  'https://diy.stackexchange.com/questions/202518/can-i-use-four-wire-cable-from-the-panel-to-create-a-two-circuit-duplex-outlet': {'context': "I am planning on adding a server to one of the closets in my house. In order to do that I need to run electrical to the location of the server. For severs they recommend having 2 independent lines of power, for redundancy, that way if one breaker trips the server won't go down. The server has 2 power supplies with independent cords. I am wondering if I can do a single 240v run from my breaker box to the location of the server and then separate the 240 to 120 and into 2 outlets, also can I run it into 2 outlet with 2 plugs, and would there be any code violations?\nThis is what I'm thinking, except this is all a 4-wire cable instead of 4 separate wires.\n\n",
#   'linked_questions': ['https://diy.stackexchange.com/questions/202550/do-ul-listed-product-specifications-or-nec-rules-take-precedence?noredirect=1',
#    'https://diy.stackexchange.com/questions/124585/what-are-the-specific-and-current-code-requirements-for-wiring-two-circuits-to-o?noredirect=1'],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/35141/isherwood',
#   'q_user_edit_time': '2020-09-03 13:52:52Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/122896/austinthemighty',
#   'q_user_owner_time': '2020-09-03 08:02:05Z',
#   'question': 'Can I use four-wire cable from the panel to create a two-circuit duplex outlet?',
#   'related_questions': ['https://diy.stackexchange.com/questions/77451/can-i-have-a-120-volt-branch-off-a-120-240-volt-circuit',
#    'https://diy.stackexchange.com/questions/89453/can-i-change-an-outlet-circuit-to-240v-nema-6',
#    'https://diy.stackexchange.com/questions/132432/wiring-two-110-v-outlets-from-one-220-v-outlet',
#    'https://diy.stackexchange.com/questions/154509/how-to-wire-a-sub-panel-from-a-15-amp-circuit-existing-run',
#    'https://diy.stackexchange.com/questions/155899/does-anyone-know-how-to-split-the-240-v-wire-components-of-a-dryer-from-the-120',
#    'https://diy.stackexchange.com/questions/159391/multi-wire-circuit-or-2-separate-120v-20a-dedicated-circuits',
#    'https://diy.stackexchange.com/questions/176714/can-i-add-a-second-disconnect-main-breaker-load-panel-from-the-meter-trough',
#    'https://diy.stackexchange.com/questions/183598/wiring-240v-where-12-2-wire-using-a-20-amp-circuit-breaker-is-present'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/receptacle',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '2'},
#  'https://diy.stackexchange.com/questions/202184/rv-pedestal-20-amp-gfci-50-amp-14-50-in-same-2-gang-box': {'context': "I'm installing an RV pedestal at my home. Out-of-the-box pedestals are not available. I'm using a 70 AMP outdoor main lug load center (HOM24L880RBCP), and a quad 2-20A 1P, 1-50A 1P breaker to feed two receptacles. Namely a 20 AMP GFCI and 50A 14-50R.\nMy question, Does NEC allow, and is it kosher, to install two separate circuits that are 50A and 20A in the same 2 gang box? If so, do they need to be de-rated?\nI'll be using 6 AWG THHN and 12 AWG THHN between the load center and the box ~ 6 inches away.\nThanks for the help.\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/35648/cueball',
#   'q_user_owner_time': '2020-08-29 12:33:43Z',
#   'question': 'RV Pedestal - 20 AMP GFCI & 50 AMP 14-50 in same 2 Gang Box?',
#   'related_questions': ['https://diy.stackexchange.com/questions/107017/can-i-install-2-30-amp-twist-lock-receptacles-in-a-2-gang-box-on-1-circuit',
#    'https://diy.stackexchange.com/questions/130117/does-the-metal-receptacle-box-for-6-30-nema-need-to-be-grounded',
#    'https://diy.stackexchange.com/questions/139740/can-i-connect-12-awg-wire-to-10-awg-in-a-junction-box',
#    'https://diy.stackexchange.com/questions/140898/proper-grounding-and-service-wire-choice-for-remote-load-center-rv-pedestal',
#    'https://diy.stackexchange.com/questions/140917/can-i-come-off-the-meter-box-to-add-a-60-amp-subpanel',
#    'https://diy.stackexchange.com/questions/153316/will-this-supply-list-work-for-a-60-amp-service',
#    'https://diy.stackexchange.com/questions/177786/tricky-three-gang-box-problems',
#    'https://diy.stackexchange.com/questions/193428/what-conduit-and-wire-for-an-outdoor-outlet-directly-to-outdoor-breaker-panel',
#    'https://diy.stackexchange.com/questions/200365/400-amp-service-to-225-amp-and-150-amp-panels'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/receptacle',
#    'https://diy.stackexchange.com/questions/tagged/code-compliance',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/201169/is-this-how-i-add-gfci-and-regular-outlet-to-existing-multi-wire-branch-circuit': {'context': 'I have a multi wire branch circuit using two 20amp breakers and a single run of 12/3 wire to a single split outlet in our laundry room.   The top outlet (black) powers the gas dryer, the bottom outlet (red) powers the washer.  We are adding a wet bar to the opposite side of the laundry room wall.  I would like to run power from that laundry outlet to a new GFCI breaker outlet (because it will be within 3 feet of a sink), and then on to another outlet that will power beverage fridges.  Can I pigtail connections to one of the outlets in the laundry room receptacle in order to provide this new power?  Will the GFCI work correctly for itself and the new outlet downstream of it?  Or will the shared neutral and ground screw up my plan?\n\n',
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '2020-08-16 00:26:10Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/122201/sjacobson',
#   'q_user_owner_time': '2020-08-16 00:15:52Z',
#   'question': 'Is this how I add GFCI and Regular Outlet to existing Multi Wire Branch Circuit, 20amp? 12/3 to 12/2 wiring with GFCI',
#   'related_questions': ['https://diy.stackexchange.com/questions/49519/how-to-wire-gfci-outlet',
#    'https://diy.stackexchange.com/questions/58173/how-can-i-add-a-gfci-receptacle-on-a-circuit-with-split-receptacles',
#    'https://diy.stackexchange.com/questions/59440/multiwire-branch-circuit-with-gfci',
#    'https://diy.stackexchange.com/questions/62423/change-gfci-outlet-switch-with-regular-switch',
#    'https://diy.stackexchange.com/questions/123696/multi-wire-branched-circuit-and-gfci',
#    'https://diy.stackexchange.com/questions/133746/bathroom-wiring-existing-light-add-bath-fan-add-gfci-outlet',
#    'https://diy.stackexchange.com/questions/149010/mwbc-multi-wire-branched-circuit-w-out-joined-breakers-how-best-to-fix',
#    'https://diy.stackexchange.com/questions/149780/110v-outlet-on-220v-circuit-with-220-gfci-to-boat-dock',
#    'https://diy.stackexchange.com/questions/165177/regular-outlet-to-gfci-outlet-with-four-wire-connections-and-no-ground'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/gfci',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/200007/proper-way-to-modernize-1940s-cabin-sub-panels': {'context': 'This cabin is located in the United States, and was built in the 1940\'s.  However, it has obviously had various electrical panels added to it after its original construction.\nI\'m starting this new question, after my original question opened a can of worms: How do I wire a modern 240V 3 prong range to a 250V 50A 3 prong outlet?\nQuestion: How do I combine all of these old panels into one new panel? Specifically, I am looking for advice on what size panel I need, and where I can locate it.  Any recommendations on a specific panel that will meet my needs? I also need to know how I can legally get all the old wires into the new panel location.\nCode Worries Is this even possible to do legally without completely rewiring everything, since I am altering existing wiring?\nPanel Advice The home has what appears to be four 240V appliances (2 outlets, 2 hard wired).  There is a range top outlet, a washing machine outlet, and two water heaters that are hard wired.\nI would like to look at changing all of the existing 120V outlets to be either AFCI or GFCI where required.  Can I do this at the breaker panel with the old wiring?  Or will I need to install GFCI outlets instead?\nExtending existing wiring to new panel How is this typically done?  A metal junction box to extend to new panel location?  If so, I\'m assuming I would need a junction box in each place that one of the old panels is being replaced, right?\nKnife Switch I would like to keep the old main knife switch so I don\'t have to get PGE involved.  Can I just run one set of wires out of that knife switch to the new panel?  If so, how?  Just run 3 wires (2 hots and a neutral) to the new panel? What about a ground? And do I have to run the new feeder cable in conduit, or can I just run Romex to the new panel from the knife switch?\n\nLocation Where can I legally mount the new panel box?  Is it allowed to be on an exterior wall?\n\n\n\nPhotos of Old Panels\nRequested Far Right Panel Image\nRequested Fuse Box Panel Image\nOutdoor Service Lines\nUpdate Proposed New Location This looks like the best place for the new panel.  I\'ll clear all of this stuff out and relocate it.  There is about 50" of walkway space in front of it, and the space is a total of 44" wide.\n',
#   'linked_questions': ['https://diy.stackexchange.com/questions/198951/how-do-i-wire-a-modern-240v-3-prong-range-to-a-250v-50a-3-prong-outlet?noredirect=1'],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '2020-07-31 21:14:51Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/120555/jimmy',
#   'q_user_owner_time': '2020-07-31 18:39:02Z',
#   'question': "Proper way to modernize 1940's cabin sub-panels",
#   'related_questions': ['https://diy.stackexchange.com/questions/18259/is-there-any-acceptable-way-to-cover-a-junction-box',
#    'https://diy.stackexchange.com/questions/25733/can-i-feed-a-sub-panel-from-a-sub-panel',
#    'https://diy.stackexchange.com/questions/91425/how-can-i-wire-two-switched-outlets-but-power-is-connected-at-the-first-outlet',
#    'https://diy.stackexchange.com/questions/138895/how-do-i-wire-a-switch-to-control-2-outlets-all-outdoor',
#    'https://diy.stackexchange.com/questions/150541/junction-box-above-ceiling-to-add-second-sub-panel-from-existing-sub-panel-feed',
#    'https://diy.stackexchange.com/questions/152522/new-20amp-circuit-via-old-conduit-or-not',
#    'https://diy.stackexchange.com/questions/164603/mini-sub-panel',
#    'https://diy.stackexchange.com/questions/167557/outlets-are-half-voltage-and-or-dont-work',
#    'https://diy.stackexchange.com/questions/191205/200-amp-service-feeding-3-sub-panels-wire-size-and-set-up-help-needed',
#    'https://diy.stackexchange.com/questions/198951/how-do-i-wire-a-modern-240v-3-prong-range-to-a-250v-50a-3-prong-outlet'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/receptacle',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '8'},
#  'https://diy.stackexchange.com/questions/192805/dryer-240-to-120-question': {'context': "I have a 240 volt dryer currently, and I want to change it out for a gas dryer that will utilize 120 volt.  Since the circuit is 240 volt 30 amp, I'd like to use the existing 6-8 gauge wire and pigtail it down to 12 gauge in the existing 2-gang box, and just cap the extra wire.  Is this within code, or should I pull the romex and run new?\n",
#   'linked_questions': ['https://diy.stackexchange.com/questions/128427/how-to-use-gfci-square-cover?noredirect=1'],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/117284/fenderbridge',
#   'q_user_owner_time': '2020-05-15 16:24:25Z',
#   'question': 'Dryer 240 to 120 question',
#   'related_questions': ['https://diy.stackexchange.com/questions/77451/can-i-have-a-120-volt-branch-off-a-120-240-volt-circuit',
#    'https://diy.stackexchange.com/questions/83728/running-a-new-240v-circuit-for-a-dryer',
#    'https://diy.stackexchange.com/questions/144057/120-240-multi-wire-branch-circuit-failed-inspection-because-of-uneven-loads',
#    'https://diy.stackexchange.com/questions/155899/does-anyone-know-how-to-split-the-240-v-wire-components-of-a-dryer-from-the-120',
#    'https://diy.stackexchange.com/questions/161042/240-volt-not-supplying-120-over-one-leg-and-the-neutral',
#    'https://diy.stackexchange.com/questions/176099/connecting-120-240-receptacles-on-the-same-circuit-breaker',
#    'https://diy.stackexchange.com/questions/176936/adding-new-240v-30-amp-outlet-by-tapping-into-existing-nema-10-30-outlet-box',
#    'https://diy.stackexchange.com/questions/178308/whirlpool-electric-dryer-works-on-120-but-not-240',
#    'https://diy.stackexchange.com/questions/179778/wiring-for-ev-charger-in-garage'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/dryer',
#    'https://diy.stackexchange.com/questions/tagged/gas',
#    'https://diy.stackexchange.com/questions/tagged/240v',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '2'},
#  'https://diy.stackexchange.com/questions/190493/running-240v-circuit-to-detached-garage': {'context': "I am trying to determine the best way possible to get a 240v outlet to my detached garage approximately 25' from the breaker panel inside the house.  I currently have 2 separate feeds to the garage now run in conduit. Each 12/2 w/ground feed is connected to its own 20 amp breaker inside the house.  I will still need 120v service for existing electrical devices in addition to the new 240v.  Any way I can utilize the existing feeds to wire a sub panel perhaps???\nNote: Existing 120v feeds each serve half the garage.\nThanks in advance!!!!\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/115979/alwdonovan',
#   'q_user_owner_time': '2020-04-19 17:34:09Z',
#   'question': 'Running 240v circuit to detached garage',
#   'related_questions': ['https://diy.stackexchange.com/questions/43886/what-subpanel-and-number-of-circuit-breakers-should-i-install-in-a-detached-gara',
#    'https://diy.stackexchange.com/questions/75069/is-the-subpanel-installation-in-a-detached-garage-correctly-done',
#    'https://diy.stackexchange.com/questions/154529/main-breaker-panel-or-main-lug-panel-for-sub-panel-in-attached-detached-garage',
#    'https://diy.stackexchange.com/questions/155963/is-a-60-amp-breaker-adequate-for-a-240v-sub-panel-to-my-garage',
#    'https://diy.stackexchange.com/questions/161343/running-240v-power-to-detached-garage-for-electric-vehicle',
#    'https://diy.stackexchange.com/questions/165021/100-amp-sub-panel-in-detached-garage-which-wire-and-breakers-for-code-complian',
#    'https://diy.stackexchange.com/questions/167399/second-100-amp-breaker-inside-existing-200-amp-residential-panel-for-new-detache',
#    'https://diy.stackexchange.com/questions/171391/30amp-sub-panel-for-ev-charger'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/subpanel',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '1'},
#  'https://diy.stackexchange.com/questions/186167/very-unsafe-looking-receptacle': {'context': 'While I was searching for duplex receptacles where one was NEMA 5 (120V) and the other was NEMA 6 (240V), I found a few normal ones that were what I was looking for (Leviton 5031, 5842, 5844, Hubbell HBL5492I), as well as this horrifying abomination:\n\nI see two immediate problems with it:\nIs there any possible way or place in which using this would be safe or legal? This seems even worse than the usual Chinese "junkstream" products, because those usually at least look okay in the picture.\n',
#   'linked_questions': ['https://diy.stackexchange.com/questions/188895/what-kind-of-receptacle-is-this?noredirect=1'],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/71950/joseph-sible-reinstate-monica',
#   'q_user_owner_time': '2020-03-07 23:27:44Z',
#   'question': 'Very unsafe-looking receptacle',
#   'related_questions': ['https://diy.stackexchange.com/questions/48308/adding-usb-dual-port-charger-receptacle-blows-mains',
#    'https://diy.stackexchange.com/questions/76463/two-appliances-fried-on-same-circuit-after-replacing-receptacle-did-i-screw-up',
#    'https://diy.stackexchange.com/questions/100283/is-a-14-pigtail-to-a-receptacle-on-a-20a-circuit-actually-an-issue',
#    'https://diy.stackexchange.com/questions/122013/can-my-houses-electricity-supply-be-upgraded',
#    'https://diy.stackexchange.com/questions/132835/can-i-install-a-60-amp-breaker-and-outlet-with-220-240-volts-63-amp-in-my-home',
#    'https://diy.stackexchange.com/questions/135720/adding-a-3-4-wire-220v-receptacle',
#    'https://diy.stackexchange.com/questions/175368/scorched-receptacle',
#    'https://diy.stackexchange.com/questions/176893/installing-gfci-into-a-box-that-feeds-two-other-outlets',
#    'https://diy.stackexchange.com/questions/177749/electrician-strangely-cut-and-capped-hot-wire-of-receptacle',
#    'https://diy.stackexchange.com/questions/182311/leviton-dimmer-3-way-remote-switch-only-turning-off'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/receptacle',
#    'https://diy.stackexchange.com/questions/tagged/240v',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '5'},
#  'https://diy.stackexchange.com/questions/184097/how-wasteful-is-a-voltage-transformer': {'context': "If an appliance that is rated for 220V is used with a 110v-to-220v transformer in a 110v country, or an appliance that is rated for 110V is used with a 220v-to-110v transformer in a 220v country, how much of the electricity is wasted? That is, how much more will it consume compared to the appliance used in its native current country?\nIf it matters which type of appliance, let's assume something like a humidifier, dehumidifier, air purifier type.\n",
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/55930/machavity',
#   'q_user_edit_time': '2020-02-06 02:46:13Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/69798/ispiro',
#   'q_user_owner_time': '2020-02-05 14:31:06Z',
#   'question': 'How wasteful is a voltage transformer?',
#   'related_questions': ['https://diy.stackexchange.com/questions/10830/how-do-i-connect-a-240-to-110v-transformers-that-measures-55v-ac-on-both-the-ho',
#    'https://diy.stackexchange.com/questions/42514/adding-undersized-fuse-to-doorbell-circuit',
#    'https://diy.stackexchange.com/questions/93000/220v-50hz-with-10amp-3-wire',
#    'https://diy.stackexchange.com/questions/106460/wiring-220v-gfci-in-a-subpanel-with-only-2-conductors',
#    'https://diy.stackexchange.com/questions/128434/how-can-i-measure-the-voltage-of-40a-transformer',
#    'https://diy.stackexchange.com/questions/143473/doorbell-voltage-drops-at-transformer',
#    'https://diy.stackexchange.com/questions/148658/transformer-core-size-and-breaker-size',
#    'https://diy.stackexchange.com/questions/155295/how-can-i-extend-an-electric-wire-without-a-large-cross-section-connector',
#    'https://diy.stackexchange.com/questions/169285/can-i-use-step-up-transformer-to-transform-110v-to-220v-for-my-window-ac'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/transformer',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '4'},
#  'https://diy.stackexchange.com/questions/181064/should-i-run-240v-for-any-supported-appliances': {'context': 'I am having my main circuit breaker panel replaced (by a licensed electrician) and he told me I can run new circuits for him to hook up to the new panel. Is there any benefit to running 240v circuits for computers, network equipment, other devices that support it?\nI would probably put a 120v outlet next to any 240v just for convenience (I was thinking on opposite sides of each stud.\n',
#   'linked_questions': ['https://diy.stackexchange.com/questions/181147/does-it-violate-us-wiring-code-to-have-non-standard-outlets?noredirect=1'],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/70045/yakatz',
#   'q_user_owner_time': '2019-12-25 22:58:14Z',
#   'question': 'Should I run 240v for any supported appliances?',
#   'related_questions': ['https://diy.stackexchange.com/questions/66253/electric-ranges-clock-timer-went-out-and-oven-bake-broil-will-not-operate',
#    'https://diy.stackexchange.com/questions/102661/are-junctions-allowed-in-an-active-panel',
#    'https://diy.stackexchange.com/questions/107797/breaker-tripping-need-advice-on-upgrade',
#    'https://diy.stackexchange.com/questions/158582/can-i-run-thhn-for-separate-washer-and-dryer-circuits-through-the-same-conduit',
#    'https://diy.stackexchange.com/questions/165235/wiring-pool-subpanel-for-pump-and-receptacles',
#    'https://diy.stackexchange.com/questions/170361/can-i-run-a-50-amp-circuit-for-a-hot-tub-from-a-60-amp-sub-panel',
#    'https://diy.stackexchange.com/questions/170878/code-exception-for-not-installing-afcis-in-kitchens',
#    'https://diy.stackexchange.com/questions/178949/wrong-installation-of-tandem-breaker-for-240v-burn-water-tank',
#    'https://diy.stackexchange.com/questions/190493/running-240v-circuit-to-detached-garage'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/wiring',
#    'https://diy.stackexchange.com/questions/tagged/120-240v',
#    'https://diy.stackexchange.com/questions/tagged/usa'],
#   'upvotes': '14'},
#  'https://diy.stackexchange.com/questions/177788/powering-a-120v-receptacle-off-of-a-240v-circuit-breaker-dedicated-to-an-applian': {'context': 'I have a 240 volt 20 amp GFCI circuit breaker powering an outdoor appliance that has 2 electric motors and a motor control unit to synchronize them.  I would like to wire a receptacle off of 1 hot leg of the 240 volt breaker instead of having to wire it to another breaker because of ease/cost.  I have been trying to see if this would be up to code.\n1 hot leg would run to a disconnect switch then to the motor control unit, the other hot leg would run to the receptacle then the disconnect switch then the control unit, then the neutral would run to the receptacle then to the control unit.\nThanks in advance for any light you can shine on this.\nEdit:  It is a 4 wire feed (hot/hot/neutral/ground).  The appliance is hardwired, the feed goes into the motor control unit, then from there out to each motor (It is a 2 motor boat lift, each lift beam/motor assembly is independent).  The motors can be powered 120v instead of 240v, but it is not currently wired that way.  It is an older appliance/lift, there is no product literature for a UL listing and the company has since closed.\n',
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/108815/bill-n',
#   'q_user_edit_time': '2019-11-06 00:30:45Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/108814/bill-n',
#   'q_user_owner_time': '2019-11-05 17:38:51Z',
#   'question': 'Powering a 120v Receptacle off of a 240v Circuit Breaker dedicated to an Appliance',
#   'related_questions': ['https://diy.stackexchange.com/questions/75087/how-to-hook-up-120v-240v-on-ac-disconnect',
#    'https://diy.stackexchange.com/questions/92675/what-breaker-configuration-should-i-use-for-a-240v-shed-circuit',
#    'https://diy.stackexchange.com/questions/93945/can-i-safely-create-another-120v-outlet-using-the-fourth-neutral-wire-from-a-4-w',
#    'https://diy.stackexchange.com/questions/124187/getting-120v-single-phase-240v-three-phase-out-of-240v-single-phase-receptical',
#    'https://diy.stackexchange.com/questions/129764/splitting-a-240v-line-into-two-120v-lines',
#    'https://diy.stackexchange.com/questions/141873/ac-powering-a-25-amp-appliance-from-2x20-amp-breakers',
#    'https://diy.stackexchange.com/questions/147495/change-from-240v-to-120v',
#    'https://diy.stackexchange.com/questions/153986/when-splitting-a-240v-circuit-what-happens-to-neutrals-amperage',
#    'https://diy.stackexchange.com/questions/159391/multi-wire-circuit-or-2-separate-120v-20a-dedicated-circuits',
#    'https://diy.stackexchange.com/questions/161042/240-volt-not-supplying-120-over-one-leg-and-the-neutral'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/circuit-breaker',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '1'},
#  'https://diy.stackexchange.com/questions/176331/adding-240v-nema-14-50-outlet-right-behind-breaker-panel': {'context': 'The breaker panel is on the outside wall, right next to my garage. I want to install a 240v outlet right behind the panel, thru the wall.\nIf i open the panel, there are those round metal covers that can be popped to run cables into the box.  Removing one shows the back of the interior drywall. ( since the breaker panel is recessed into the exterior wall)\nIdea is simple. Add a 50amp breaker and just drill thru the drywall, run the appropriate cables (about 3 feet)  thru the hole and straight into one of these:\nLevinton 50 Amp, 125/250 Volt, NEMA 14-50R, 3P, 4W, Surface Mounted Receptacle\nNo wires would be exposed.\nWould this be against code or any safety hazards that i need to be aware of?\n',
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/47125/harper-reinstate-monica',
#   'q_user_edit_time': '2019-10-13 01:06:50Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/72227/user1957413',
#   'q_user_owner_time': '2019-10-13 00:16:12Z',
#   'question': 'Adding 240v (NEMA 14-50) outlet right behind breaker panel',
#   'related_questions': ['https://diy.stackexchange.com/questions/4244/what-is-the-proper-wiring-for-a-nema-14-30-240v-receptacle',
#    'https://diy.stackexchange.com/questions/25061/should-i-use-3-wire-or-4-wire-for-a-range',
#    'https://diy.stackexchange.com/questions/57447/what-size-breaker-should-i-use-to-feed-an-electrical-panel-for-our-addition',
#    'https://diy.stackexchange.com/questions/89453/can-i-change-an-outlet-circuit-to-240v-nema-6',
#    'https://diy.stackexchange.com/questions/161343/running-240v-power-to-detached-garage-for-electric-vehicle',
#    'https://diy.stackexchange.com/questions/169152/subpanel-vs-220v-240v-nema-14-50',
#    'https://diy.stackexchange.com/questions/171504/220v-gfci-and-amps',
#    'https://diy.stackexchange.com/questions/176936/adding-new-240v-30-amp-outlet-by-tapping-into-existing-nema-10-30-outlet-box',
#    'https://diy.stackexchange.com/questions/177932/is-10-2-cable-appropriate-for-a-240v-30a-garage-heater-outlet',
#    'https://diy.stackexchange.com/questions/190218/can-i-run-two-6-3-nm-cables-up-the-same-2x4'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/code-compliance',
#    'https://diy.stackexchange.com/questions/tagged/garage',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/176099/connecting-120-240-receptacles-on-the-same-circuit-breaker': {'context': "I want to add a branch circuit to the control panel using 12/3 wire and protected by 20 amp double pole circuit breaker. Is it safe to connect multiple duplex receptacles 120 volts and 240 volts on the same circuit? In this setup, I'd use black, red, and ground for the duplex 240 volts 20 amp receptacle and I'd use black, white and ground for the other 110 volts 20 amp duplex receptacle.\nI live in Ontario, Canada.\n",
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/55930/machavity',
#   'q_user_edit_time': '2019-10-09 03:09:39Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/107875/ehab-teima',
#   'q_user_owner_time': '2019-10-09 02:56:51Z',
#   'question': 'Connecting 120/240 receptacles on the same circuit breaker',
#   'related_questions': ['https://diy.stackexchange.com/questions/61256/can-i-wire-a-box-with-two-120-volt-duplex-outlets-each-wired-to-one-leg-of-a-240',
#    'https://diy.stackexchange.com/questions/77400/ac-voltage-drop',
#    'https://diy.stackexchange.com/questions/77451/can-i-have-a-120-volt-branch-off-a-120-240-volt-circuit',
#    'https://diy.stackexchange.com/questions/123246/all-my-240-circuits-arent-working-anymore-in-sub-panel-but-the-sub-panel-is-get',
#    'https://diy.stackexchange.com/questions/143613/wiring-options-for-14-3-nm-b-cable-and-two-single-pole-15-amp-circuit-breakers',
#    'https://diy.stackexchange.com/questions/144057/120-240-multi-wire-branch-circuit-failed-inspection-because-of-uneven-loads',
#    'https://diy.stackexchange.com/questions/155899/does-anyone-know-how-to-split-the-240-v-wire-components-of-a-dryer-from-the-120',
#    'https://diy.stackexchange.com/questions/161042/240-volt-not-supplying-120-over-one-leg-and-the-neutral',
#    'https://diy.stackexchange.com/questions/192805/dryer-240-to-120-question',
#    'https://diy.stackexchange.com/questions/197343/convert-mwbc-to-single-240v-receptacle'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/receptacle',
#    'https://diy.stackexchange.com/questions/tagged/120-240v',
#    'https://diy.stackexchange.com/questions/tagged/mwbc'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/175450/electrical-service-sizing-mix-up-in-mexico': {'context': 'The national electrical supply company of Mexico called "Comisión Federal de Electricidad" (CFE) oficially instructs users to install:\nThe NEC is being translated almost word by word and published in Mexico under the name NOM-001-SEDE-2018 (2018 is the latest I can find)\nThere is no real enforced implementation of this "Norma Oficial Mexicana", neither any inspection at service connection anywhere throughout the nation which makes it more of a guide for the educated electrician.\nThe actual service drop of the utility is usually #6 aluminium wire. (As found in their own published specs - See Table 1; Rated between 40-55A depending on the type by the NFPA 70 NEC edition 2020 - See Table 310.16)\nThe actual meter (if it is digital and up to date [there\'s still a lot of analog meters used from old installations]) is rated 15(100)A in any case.\nMost homes in Mexico use mainly gas for any heat appliances and only cold water for laundry although there is common use of air conditioning units in the north.\nA common household load would include appliances such as a relatively large fridge, several washers w/o dryers, a steam iron, a microwave, one or several blenders and lots of consumer electronics. Occasionally a power tool for a short period of time.\nMost shops with extensive use of high demanding electrical tools including high capacity welders will nevertheless have a simple 120V or 240V single phase service contract.\nLots of, if not most, electricians will install a 50A main breaker nonetheless knowing that that\'s what a #8Cu THW and a #6Al can carry.\nSo there\'s quite a few things that don\'t add up here and it makes one wonder about the quality of the provided service. The disconnect means requirement of 30A is way lower than what the wiring instructions would be capable of (50A) for a pure 120V service and very boldly limits the end users consumption.\nThe fact that the instructions for a 240V service are not altered in any way other than requiring an additional wire and a different meter base is just outrageous and makes it per their own definition completely useless unless you want to permanently trip the main service interrupt with your 240V appliances.\nIt appears that the only power providing utility in the country does not necessarily adhere to the nationally published electrical code or even less promote it. (In fact in reality most of their personell wouldn\'t even know a code existed and any educated layman would cringe over many of the installations done by the utility)\n',
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/-1/community',
#   'q_user_edit_time': '2020-06-16 10:07:27Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/99006/marian',
#   'q_user_owner_time': '2019-09-29 21:41:48Z',
#   'question': 'Electrical service sizing mix up in Mexico',
#   'related_questions': ['https://diy.stackexchange.com/questions/105694/optimal-breaker-configuration-for-split-phase-mains-power',
#    'https://diy.stackexchange.com/questions/105853/upgrade-electric-service-from-100a-to-200a',
#    'https://diy.stackexchange.com/questions/122013/can-my-houses-electricity-supply-be-upgraded',
#    'https://diy.stackexchange.com/questions/124187/getting-120v-single-phase-240v-three-phase-out-of-240v-single-phase-receptical',
#    'https://diy.stackexchange.com/questions/151105/tapping-neutral-in-service-entrance',
#    'https://diy.stackexchange.com/questions/161196/confusion-about-main-disconnect-ampacity',
#    'https://diy.stackexchange.com/questions/166963/electrical-supply-to-detached-office',
#    'https://diy.stackexchange.com/questions/186428/does-a-new-manufactured-home-on-permanent-foundation-need-a-shutoff-within-30ft',
#    'https://diy.stackexchange.com/questions/200616/seeking-advice-on-how-to-rearrange-existing-breakers-and-add-2-circuits-includi',
#    'https://diy.stackexchange.com/questions/202514/can-i-put-the-sub-panel-for-my-attached-garage-in-the-attic'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/electrical',
#    'https://diy.stackexchange.com/questions/tagged/electrical-panel',
#    'https://diy.stackexchange.com/questions/tagged/circuit-breaker',
#    'https://diy.stackexchange.com/questions/tagged/120-240v'],
#   'upvotes': '7'},
#  'https://diy.stackexchange.com/questions/174288/future-proofing-for-240v-outlet': {'context': "I currently have a 12A EVSE that takes either 120V or 240V and uses a normal three-prong (NEMA 5-15) plug. I am looking to install a 240V outlet on a 50A circuit breaker to use with this EVSE, but I'm wondering which receptacle to use with this new outlet. I've ruled out a NEMA 5-15/5-20 receptacle, so I will need an adapter to use my current EVSE for any outlet I install. Would it make more sense to install a 14-50R receptacle, a 6-50 receptacle, or some other type?\n",
#   'linked_questions': ['https://diy.stackexchange.com/questions/110385/nema-6-15-to-nema-5-15-hot-hot-ground?noredirect=1'],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/35141/isherwood',
#   'q_user_edit_time': '2019-09-24 18:25:26Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/86552/palswim',
#   'q_user_owner_time': '2019-09-13 00:34:14Z',
#   'question': 'Future proofing for 240V outlet',
#   'related_questions': ['https://diy.stackexchange.com/questions/46278/code-compliance-with-120-240v-outlet',
#    'https://diy.stackexchange.com/questions/46826/is-it-possible-and-safe-to-adapt-a-4-prong-dryer-outlet-to-a-nema-6-20',
#    'https://diy.stackexchange.com/questions/109041/20a-and-50a-receptacle-on-30a-circuit',
#    'https://diy.stackexchange.com/questions/117965/new-220v-outlet-for-expansion',
#    'https://diy.stackexchange.com/questions/124187/getting-120v-single-phase-240v-three-phase-out-of-240v-single-phase-receptical',
#    'https://diy.stackexchange.com/questions/153961/is-this-240v-outlet-undersized',
#    'https://diy.stackexchange.com/questions/178208/running-240v-from-two-separate-120v-receptacles',
#    'https://diy.stackexchange.com/questions/181147/does-it-violate-us-wiring-code-to-have-non-standard-outlets',
#    'https://diy.stackexchange.com/questions/191387/can-i-use-an-adapter-to-plug-a-230v-air-conditioner-into-a-120v-outlet',
# ...
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/35141/isherwood',
#   'q_user_edit_time': '2020-07-17 20:29:39Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/108952/marbletravis',
#   'q_user_owner_time': '2020-07-16 21:38:41Z',
#   'question': 'Why is there a musty smell from my HVAC system even after coil cleaning?',
#   'related_questions': ['https://diy.stackexchange.com/questions/16606/what-could-be-wrong-with-my-a-c-unit',
#    'https://diy.stackexchange.com/questions/52786/is-it-safe-to-use-an-hvac-system-even-though-the-duct-wrap-contains-asbestos',
#    'https://diy.stackexchange.com/questions/68128/no-ac-i-have-a-few-hvac-troubleshooting-questions',
#    'https://diy.stackexchange.com/questions/90929/five-year-mystery-unable-to-find-source-of-burning-smell-from-hvac-system',
#    'https://diy.stackexchange.com/questions/119487/furnace-blower-motor-runs-briefly-then-turns-off',
#    'https://diy.stackexchange.com/questions/122654/ac-frozen-tubes-no-air-flowing-when-fan-on-and-system-off',
#    'https://diy.stackexchange.com/questions/143875/how-to-i-eliminate-the-smell-coming-from-my-mitsubishi-mini-split-units',
#    'https://diy.stackexchange.com/questions/194915/should-my-ac-condenser-and-evaporator-be-the-same-size',
#    'https://diy.stackexchange.com/questions/195238/evaporator-coil-cold-but-not-ice-cold'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/hvac',
#    'https://diy.stackexchange.com/questions/tagged/air-conditioning',
#    'https://diy.stackexchange.com/questions/tagged/furnace',
#    'https://diy.stackexchange.com/questions/tagged/smell'],
#   'upvotes': '1'},
#  'https://diy.stackexchange.com/questions/197796/sewer-smell-in-bathroom-only-when-central-a-c-is-on-and-kitchen-sink-is-running': {'context': "This is a weird one, and have come across multiple handymen and none of them can pinpoint the problem when I describe it. Though they have never been in the room when it happens.\nHere is the scenario...\nWe leave the central A/C on all day because we have big dogs in the CA heat, so when we get home, the A/C is running. When we turn on the water faucet in the kitchen sink, immediately one of the bathrooms emits a sewer odor that lasts for about 10 minutes. This happens consistently so much that the first thing when I get home is to open the bathroom window before my wife starts using the sink.\nThe details...\nI have placed my face in the toilet, bathroom sink, shower drain, and A/C vent in the bathroom and cannot pinpoint where the smell is coming from. The bathroom in question has a wall that faces the front of the house and that part of the house is where the main water supply line is. When the scenario with the smell is happening in the bathroom, if I go outside my house into that part of the front of the house, I can also smell the bad odor, but not as strongly as in the bathroom.\nI once had a plumber here to see if I could create the smell. It was about 9am and I turned on the A/C for about 20 minutes then turned on the kitchen faucet, and OF COURSE it didn't smell, so he couldn't help pinpoint the situation. I guess a prerequisite is that the A/C be on for hours or all day.\nIn conclusion, the smell doesn't come in any other scenario. It's just the combination of the A/C and kitchen sink (no other sink in the house causes it). And the smell is only that bathroom. I have another bathroom and no problem there. I've had the HVAC unit for 3 years and it's really been happening for a year now.\nAsk me any questions you may have and thank you in advance for reading this long story and for any input you may have.\n",
#   'linked_questions': [],
#   'q_user_edit_link': 'https://diy.stackexchange.com/users/34147/freeman',
#   'q_user_edit_time': '2020-07-16 11:13:21Z',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/119916/hugo-moran',
#   'q_user_owner_time': '2020-07-16 04:35:26Z',
#   'question': 'Sewer smell in bathroom ONLY when central a/c is on and kitchen sink is running water',
#   'related_questions': ['https://diy.stackexchange.com/questions/6709/how-can-i-fix-the-sewer-smell-in-my-bathroom',
#    'https://diy.stackexchange.com/questions/78563/water-in-kitchen-sink-smells',
#    'https://diy.stackexchange.com/questions/85306/rotten-egg-smell-in-cold-water-only-bathroom-sink-of-new-home',
#    'https://diy.stackexchange.com/questions/93095/foul-smell-in-bathroom-only-when-air-conditioning-is-not-blowing-running',
#    'https://diy.stackexchange.com/questions/101267/foul-smell-in-my-bathroom-when-i-run-water-anywhere-in-my-house',
#    'https://diy.stackexchange.com/questions/164661/warm-weather-smell-again',
#    'https://diy.stackexchange.com/questions/174355/urine-smell-in-bathroom-sink',
#    'https://diy.stackexchange.com/questions/185478/sewage-smell-from-kitchen-sink-area',
#    'https://diy.stackexchange.com/questions/186236/sink-smell-and-slimy-p-trap'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/plumbing',
#    'https://diy.stackexchange.com/questions/tagged/hvac',
#    'https://diy.stackexchange.com/questions/tagged/air-conditioning',
#    'https://diy.stackexchange.com/questions/tagged/smell',
#    'https://diy.stackexchange.com/questions/tagged/sewer'],
#   'upvotes': '2'},
#  'https://diy.stackexchange.com/questions/197431/no-condensation-coming-from-my-ac': {'context': "It's humid out yet there's no condensation coming from my ac. Thermostat set at 78 and that's what temp is inside.\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/119736/user119736',
#   'q_user_owner_time': '2020-07-12 00:29:56Z',
#   'question': 'No condensation coming from my ac',
#   'related_questions': ['https://diy.stackexchange.com/questions/197/should-my-evaporator-be-hissing-should-cold-air-be-blowing-from-it',
#    'https://diy.stackexchange.com/questions/7776/ac-coolant-pipe-has-condensation-and-leaks-inside-wall',
#    'https://diy.stackexchange.com/questions/29220/is-it-possible-to-control-the-speed-of-the-fan-on-my-central-a-c-unit',
#    'https://diy.stackexchange.com/questions/29861/a-c-condensation-from-duct-getting-into-drywall',
#    'https://diy.stackexchange.com/questions/30022/is-it-ok-for-air-conditioning-condensation-to-drip-right-next-to-the-house',
#    'https://diy.stackexchange.com/questions/45025/air-conditioner-woes-water-pooling-in-basement-condensation-on-ducts-frost-on',
#    'https://diy.stackexchange.com/questions/69843/why-does-ac-unit-need-condensation-drain-trap',
#    'https://diy.stackexchange.com/questions/95086/blower-shut-off-but-the-ac-unit-ran-for-20-30-minutes-afterward',
#    'https://diy.stackexchange.com/questions/164248/what-does-temporary-hold-mean-on-a-bge-thermostat',
#    'https://diy.stackexchange.com/questions/200069/ac-not-shutting-of-automatically'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/air-conditioning'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/197400/how-to-silence-a-loud-ptac-ac-unit': {'context': 'I moved into an apartment with a loud (and somewhat not so cooling) PTAC in-wall AC unit. Each room has its own, a total of 3. The land lord is super cheap and only replaced the 8+ year old unit in the bedroom. That bedroom unit is relatively quiet and very efficiently cooling the room. The living room one is loud and does not cool so well.\nWhat can I do to reduce the noise?\n',
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/35919/kingsinnersoul',
#   'q_user_owner_time': '2020-07-11 14:40:46Z',
#   'question': 'how To Silence a Loud PTAC AC Unit?',
#   'related_questions': ['https://diy.stackexchange.com/questions/3039/how-do-i-stop-the-dripping-noise-from-my-gutters',
#    'https://diy.stackexchange.com/questions/140435/is-it-possible-to-use-ducts-with-a-window-a-c-unit',
#    'https://diy.stackexchange.com/questions/144170/how-to-get-cold-air-from-one-room-to-another',
#    'https://diy.stackexchange.com/questions/166853/my-ac-blows-warm-air',
#    'https://diy.stackexchange.com/questions/167215/how-do-i-deaden-the-sound-of-water-dripping-on-metal',
#    'https://diy.stackexchange.com/questions/185551/reducing-wind-noise-inside',
#    'https://diy.stackexchange.com/questions/189830/hissing-sound-after-filling-ac-unit-refrigerant',
#    'https://diy.stackexchange.com/questions/198786/what-is-the-deltat-test-for-a-ptac-ac'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/hvac',
#    'https://diy.stackexchange.com/questions/tagged/air-conditioning',
#    'https://diy.stackexchange.com/questions/tagged/noise-reduction'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/197373/window-a-c-remote-temperature-sensor': {'context': 'I have an LG LW1217ERSM 12,000 BTU window A/C unit and was wondering if it is possible to connect a remote temperature sensor to the unit.\nFor example, the unit is set to 72 degrees but the temperature in another room is 80 degrees. With the remote temperature sensor placed in the 80 degree room, the unit would continue to cool until that room is also brought down to 72 degrees. Unfortunately this unit does not seem to have this feature so I was wondering if it is possible to modify the unit.\nThanks!\n',
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/52819/fire-water',
#   'q_user_owner_time': '2020-07-11 01:23:49Z',
#   'question': 'Window A/C Remote Temperature Sensor',
#   'related_questions': ['https://diy.stackexchange.com/questions/8255/besides-insulation-and-air-conditioning-unit-what-else-is-there-to-check-if-my',
#    'https://diy.stackexchange.com/questions/15240/is-my-window-air-conditioner-cooling-properly',
#    'https://diy.stackexchange.com/questions/31918/does-a-daikin-ac-remember-the-settings-when-it-was-last-turned-on-or-what-the-r',
#    'https://diy.stackexchange.com/questions/116334/window-air-conditioner-between-living-room-and-enclosed-porch',
#    'https://diy.stackexchange.com/questions/117143/8-000-btu-vs-10-000-btu-portable-a-c-unit-will-the-10-000-btu-unit-cool-the-s',
#    'https://diy.stackexchange.com/questions/117334/how-does-the-decibel-rating-vary-with-the-btu-capacity-of-an-air-conditioning-un',
#    'https://diy.stackexchange.com/questions/140435/is-it-possible-to-use-ducts-with-a-window-a-c-unit',
#    'https://diy.stackexchange.com/questions/166853/my-ac-blows-warm-air'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/air-conditioning'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/197364/weird-filter-size-for-airconditioner': {'context': 'I have a weird size air-conditioner filter that is 414 x 544 mm, which is a little over 16" and a little over 21".\nWhen I go to to the hardware store here in Canada, they carry all sorts of filter sizes, but nothing that matches my filter, so I had to cut and tape one up.\nAlso, when the label says 16" on a filter, it is actually less than 16" for the product? Very confusing.\nWhat is going on here?\nDid I end up with a European filter in Canada, maybe? Or is something else going on?\nThe brand name on it is Carrier and model number is FB4CNF036.\n\n',
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/78393/bram',
#   'q_user_owner_time': '2020-07-11 00:02:48Z',
#   'question': 'Weird filter size for airconditioner',
#   'related_questions': ['https://diy.stackexchange.com/questions/13968/what-could-be-causing-my-spa-filter-to-clog-regularly-often-and-how-can-i-fix-i',
#    'https://diy.stackexchange.com/questions/21427/what-should-i-look-for-when-shopping-for-a-kitchen-faucet-water-filter',
#    'https://diy.stackexchange.com/questions/26680/can-a-non-expandable-filter-be-used-in-place-of-an-ez-flex-furnace-filter',
#    'https://diy.stackexchange.com/questions/38356/which-way-should-furnace-filter-face',
#    'https://diy.stackexchange.com/questions/57477/enclosure-for-whole-house-water-filter',
#    'https://diy.stackexchange.com/questions/116887/identifying-well-water-filter',
#    'https://diy.stackexchange.com/questions/125390/water-filter-for-shower-boiler',
#    'https://diy.stackexchange.com/questions/166770/air-filter-size-for-new-to-me-home-hvac'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/air-conditioning',
#    'https://diy.stackexchange.com/questions/tagged/filter',
#    'https://diy.stackexchange.com/questions/tagged/measurement'],
#   'upvotes': '0'},
#  'https://diy.stackexchange.com/questions/197218/curtains-to-direct-airflow': {'context': "All the cold air from my AC flows through a stairwell and into the basement. The entrance to the basement is the through a doorless opening on the 1st floor.\nI am planning to put up a curtain in that entryway to block the precious cold air from flowing down to the basement. I'm thinking of using a tension rod since I don't care if there is an opening at the top of the curtain. only the hot air would flow through. However the bottom must be touching the floor and should seal off any cold airflow.\nWould this method work? If so, is there a particular kind of curtain available with weighted bottoms or rubber bottom that can stop airflow?\nAny insight would help! Thank you\n",
#   'linked_questions': [],
#   'q_user_edit_link': '',
#   'q_user_edit_time': '',
#   'q_user_owner_link': 'https://diy.stackexchange.com/users/118571/thentangler',
#   'q_user_owner_time': '2020-07-09 06:21:18Z',
#   'question': 'Curtains to direct airflow',
#   'related_questions': ['https://diy.stackexchange.com/questions/59115/adding-vents-to-duct',
#    'https://diy.stackexchange.com/questions/61001/how-can-i-improve-second-floor-hvac-performance',
#    'https://diy.stackexchange.com/questions/114322/can-i-move-warm-air-from-2nd-floor-to-basement-to-help-with-heating',
#    'https://diy.stackexchange.com/questions/114948/high-humidity-in-an-unused-air-conditioned-finished-basement-dehumidifier',
#    'https://diy.stackexchange.com/questions/140287/will-adding-a-cool-air-return-in-the-basement-help-with-summer-ac-power-usage',
#    'https://diy.stackexchange.com/questions/150685/ecobee-smart-thermostat-using-room-sensor-as-primary-control',
#    'https://diy.stackexchange.com/questions/168015/should-i-move-all-my-window-air-conditioners-to-the-upper-floor-for-better-effic',
#    'https://diy.stackexchange.com/questions/181715/what-should-i-do-with-the-airflow-in-a-sealed-off-conditioned-crawlspace',
#    'https://diy.stackexchange.com/questions/195159/redirecting-cold-air-from-a-floor-vent-to-ceiling'],
#   'tags': ['https://diy.stackexchange.com/questions/tagged/hvac',
#    'https://diy.stackexchange.com/questions/tagged/air-conditioning'],
#   'upvotes': '0'},
#  ...}

# %%
for key in data.keys():
    tags = []
   
    for tag in data[key]['tags']:
        split_tag = tag.split("/")
        tags.append(split_tag [-1])
    data[key]['tags'] = tags
    

for key in data.keys():
    questions = []
    for question in data[key]['related_questions']:
        split_question = question.split("/")
        questions.append(split_question[-1])
    data[key]['related_questions'] = questions

# %%
key_select = list(data.keys())[1]
data[key_select]
# Out:
# {'context': 'I was wondering if I could run 120v wires inside in a larger conduit that has higher voltage wires 240v, in a smaller piece of conduit?\nThe reason I ask is that I have a manufactured home and when they installed the 240v wiring coming from the meter it is run under the house in the crawlspace. It\'s not in conduit untill it enters the bottom of the electrical panel. When the water pump (120v) was installed they just ran it into the conduit with the 240v wiring.\nI know for certain you can\'t run low and high voltage in the same conduit, but I thought that if I ran a 1/2" conduit inside the 2" for the 120v that would rectify the violation.\n',
#  'linked_questions': [],
#  'q_user_edit_link': 'https://diy.stackexchange.com/users/89023/jeff-wheeler',
#  'q_user_edit_time': '2020-09-25 13:41:17Z',
#  'q_user_owner_link': 'https://diy.stackexchange.com/users/123731/norman-sobieck',
#  'q_user_owner_time': '2020-09-25 10:05:54Z',
#  'question': 'Can I run conduit containing 120V wires inside larger conduit for 240V wires?',
#  'related_questions': ['is-there-an-advantage-to-using-emt-over-plastic-flexible-conduit-for-low-voltage',
#   'which-cable-conduit-should-i-use-to-run-a-new-240-volt-line-for-an-oven',
#   'conduit-size-for-sub-panel-run',
#   'can-i-run-thhn-for-separate-washer-and-dryer-circuits-through-the-same-conduit',
#   '8-thhn-in-conduit-for-50-amp-circuits',
#   'when-derating-for-wires-in-conduit-do-you-round-up-or-down',
#   'does-a-new-manufactured-home-on-permanent-foundation-need-a-shutoff-within-30ft',
#   'how-should-i-run-this-conduit-for-security-cameras-across-a-flat-roof',
#   'can-i-replace-a-single-dedicated-20a-120v-receptacle-with-a-20a-240v-receptacle',
#   'leave-extra-wire-in-conduit-for-future-expansion'],
#  'tags': ['wiring', 'conduit', '120-240v'],
#  'upvotes': '1'}

# %%
with open('data.json', 'w') as fp:
    json.dump(data, fp)

# %%
df = pd.read_json('data.json')
df.head()
# Out:
#                  https://diy.stackexchange.com/questions/204261/i-have-a-champion-120v-generator-i-want-to-use-it-to-plug-into-a-preinstalled-w  ... https://diy.stackexchange.com/questions/202571/how-to-drain-a-specific-heating-zone
# question          I have a Champion 120V generator, I want to us...                                                                              ...              how to drain a specific heating zone?
# context           I have a new champion generator, 120volt at 20...                                                                              ...  I have hot water baseboard heating, with three...
# upvotes                                                           0                                                                              ...                                                  0
# tags                                                     [120-240v]                                                                              ...                                    [zoned-heating]
# q_user_edit_time                               2020-09-26 18:23:53Z                                                                              ...
#
# [5 rows x 56431 columns]

# %%
df = df.T

# %%
df = df.reset_index()

# %%
df = df.drop(df.columns[0], axis=1)

# %%
df.drop(df.columns[[ 1, 2, 4, 5, 6, 7, 8, 9]], axis = 1, inplace = True)
df.head()
# Out:
#                                             question                                              tags
# 0  I have a Champion 120V generator, I want to us...                                        [120-240v]
# 1  Can I run conduit containing 120V wires inside...                       [wiring, conduit, 120-240v]
# 2  30V on 120 circuit - swapped dishwashers and c...  [electrical, wiring, electrical-panel, 120-240v]
# 3                 How much 120 from 240 is too much?                          [wiring, shed, 120-240v]
# 4  Is it possible to wire a 240v outlet so that a...    [electrical, electrical-panel, 240v, 120-240v]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56431 entries, 0 to 56430
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  56431 non-null  object
#  1   tags      56431 non-null  object
# dtypes: object(2)
# memory usage: 881.9+ KB

# %%
from ast import literal_eval
df['tags'] = df.tags.apply(lambda x: literal_eval(str(x)))

# %%
df[['cat1','cat2' ,'cat3' , 'cat4' , 'cat5']] = pd.DataFrame(df.tags.tolist(), index= df.index)

# %%
df.head(5)
# Out:
#                                             question  ...  cat5
# 0  I have a Champion 120V generator, I want to us...  ...  None
# 1  Can I run conduit containing 120V wires inside...  ...  None
# 2  30V on 120 circuit - swapped dishwashers and c...  ...  None
# 3                 How much 120 from 240 is too much?  ...  None
# 4  Is it possible to wire a 240v outlet so that a...  ...  None
#
# [5 rows x 7 columns]

# %%
dict = {'electrical' : ['conductors', 'nec', 'splicing', 'socket',	'multiway-switch',	'dimmer-switch',	'switch', 'testing', 'troubleshooting', 'electric-vehicle', 'inverter', 'relay', 'motor', 'inspection', 'outlets', 'transfer-switch', 'neutral' , 'timer', 'weather-resistant', 'welding', 'utilities', 'capacitor', 'generator', 'power-backup' ,'afci', 'service' , 'electrical-panel', 'gfci', 'extension-cord', 'receptacle' ,'circuit-breaker' ,'circuit' ,'conduit' ,'breaker-box' ,'code-compliance' ,'subpanel' ,'junction-box' ,'distribution-board' ,'rewire' ,'cable-management' ,'junction' ,'electric-motor','transformer', 'electrical-distribution' ,'fuse-breaker ','electric-fence' ,'surge-suppression','circuit', '240v' ,'voltage' ,'low-voltage' ,'cord-and-plug' ,'connectors' ,'electronics' ,'extension ','adapter' ,'mwbc' ,'thermocouple' ,'splices' ,'120-240v' ,'grounding' ,'ground' ,'bonding' ,'grounding-and-bonding ','resistance' ,'ups' ,'lightning' ],
        'hvac' : ['condensate', 'condensation', 'register', 'radiant-heating', 'heat', 'central-air', 'carrier', 'ductwork', 'temperature', 'lennox', 'hydronic', 'air-compressor','compressor', 'zoned-heating', 'humidity', 'water-circulating-heating','ventilation', 'exhaust-fan', 'air-conditioning' ,'air', 'dehumidifier', 'central-heating', 'cooling', 'heater', 'thermostat-c-wire', 'thermostat', 'aquastat', 'exhaust-vent', 'air-conditioner','evaporative-cooling', 'ducts','electric-heat','heat-pump' ],
       'plumbing': ['plumbing-fixture', 'water-pressure',	'septic',	'outdoorfaucet',	'sump',	'spout',	'rough-in' ,	'galvanic-corrosion' ,	'downspout ',	'vanity '	,'freezing',	'irrigation',	'laundry',	'cartridge',	'blockage',	'rubber' ,	'pressure' ,	'shutoff',	'water-tank' ,	'chemicals' ,	'overflow',	'clog ',	'backflow-preventer',	'venting'	,'well-pump','	cpvc' ,	'taps' ,	'spigot',	'abs' ,	'septic-tanks', '	plumbing-fixture' ,	'pex' ,	'pipe' ,	'sink' ,	'drainage' ,	'pump' ,	'sewer'	'vent' ,	'drain-waste-vent' ,	'cistern'	'faucet',	'gutters',	'drains' ,	'drain' ,	'valve' ,'saddle-valve' , 'hose' ,	'p-trap' ,	'water-hammer' ,	'pond' ,	'water' ,	'odors','	french-drain' ,	'sump-pump'],
        'wiring' : ['cables',	'coaxial-cable' ,	'knobs',	'wire ',	'phone-wiring' ,	'data-wiring ',	'cable-management' ,	'knob-and-tube' ,	'aluminum-wiring' ,	'coax'],
        'lighting': ['lamp' ,	'bulb ',	'halogen' ,	'light-fixture',	'retrofit' ,	'recessed-lighting' ,	'light' ,	'pole',	'skylight', 'led',	'cfl',	'fluorescent',	'lamp-tombstone' ,	'ballast'],
       ' walls' :['load-bearing' ,	'damp-proof-course' ,	'drywall' ,	'render' ,	'rope-knots',	'hanging',	'mount' ,	'retaining-wall' ,	'drywall-anchor',	'patching-drywall',	'access-panel',	'taping',	'mudding ',	'drywall-mud ',	'wallpaper',	'mounting' ,	'load '],
        'materials' : ['ledger',	'stucco' ,	'pvc' ,	'glue' ,	'duct-tape' ,	'polyurethane' ,	'adhesive' ,	'porcelain',	'spackling-paste',	'asphalt',	'stone' ,	'limestone' ,	'quartz' ,	'sealer ',	'grout' ,	'studs',	'acrylic' ,	'brick' ,	'steel' ,	'glass' ,	'fiberglass' ,'vinyl-siding' ,	'siding' ,	'stainless' ,	'sheet-metal' ,	'slate' ,'soil ',	'corner-bead' ,	'mosaic' ,	'rock' ,	'cast-iron' ,	'porcelain' ,	'gravel' 	,'sealant' ,	'metal' ,	'cement' ,	'pavers' ,	'sander' ,	'copper' ,	'lumber' ,	'plastic' ,	'joists' ,	'frame' ,	'aluminum' ,	'granite',	'tape' ,	'epoxy'	,'copper-tubing' ,	'thinset' ,	'backer-board' ,	'particle-board' ,'marble' ,'concrete' ,	'silicone' ,	'board '],
         'exterior-maintenance' : ['play-structures' ,	'pergola',	'walkway' ,	'carport' ,	'gable' ,	'chimney' ,'sidewalk',	'metal-roof',	'recycling' ,	'roofing ' ,	'moss' ,	'roof' ,	'disposal' ,	'deck' ,	'garbage-disposal' ,	'pool' ,	'trash-can' ,	'fascia' ,	'driveway'	,'gate-post' ,	'landscaping' ,	'fence' ,'shed' ,	'grass' ,	'gardening' ,	'railing' ,	'outdoor' ,	'ceiling' ,	'foundation'],
        'interior-maintenance ' :['floor ',	'steps' ,	'stairs' ,	'slab' ,	'column' ,	'backsplash' ,	'beam' ,	'furnace',	'fire-pit' ,	'popcorn' ,	'hearth' ,	'fireplace' ,	'frost ' ,	'frost-heave' ,	'stuck' ,	'trim' ,	'trim-carpentry' ,	'maintenance'],
      'appliances' :  ['fridge',	'blower' ,	'clothes-washer' ,	'ductless' ,	'hot-water' ,	'television' ,	'tv-antenna' ,	'air-filter' ,	'oven' ,	'refrigerator','washing-machine' ,	'boiler' ,	'ice-maker' ,	'washer' ,	'dryer',	'range' ,	'woodstove' ,	'stove' ,	'angle-grinder' ,	'microwave-oven' ,	'fridge' ,	'microhood',	'mini-split' ,'exhaust' ,	'blower',	'water-softener' ],
       'hardware-tools' : ['motion-sensor','tools','hardware',	'joinery ',	'rivets' ,	'angle-grinder' ,	'threading',	'excavator' ,	'radon' ,	'multimeter' ,	'bolts' ,	'bits' ,	'tongue-and-groove' ,	'drill' ,'shingles ',	'gauge ',	'nails' ,	'grinder' ,	'lawn-mower' ,	'screwdriver' ,	'screws' ,	'ball-bearing' ,	'radiator' ,	'fastener' ,	'framing-fasteners' ,	'fastening' ,	'powertools' ,	'hinges' ,	'hand-tools' ,	'deadbolt' ,	'multimeter' ,	'measuring ',	'yard-hydrant' 	'pressure-washer' ,	'indicator' ,	'angle' ,	'lathe ' , 'regulator' ,	'flange', 'circular-saw' ,	'bandsaw ',	'table-saw' ,	'chainsaw' ,	'miter' , 'saw ', 'ladder', 'mailbox', 'curtain-rail', 'support', 'handrail',	'magnet',	'p-trap''solder',	'meter',	'soldering',	'flashing'],
        'furniture' :['desk',	'custom-cabinetry' ,	'storage '	'shelving' ,	'shelf',	'closet ' ,	'span-tables' ,	'drawers'	'brackets',	'self-assembly-furniture' ,	'bench',	'table' ,'	wooden-furniture',	'antique',	'mirror','carpet'],
      'safety' : ['child-safety',	'security',	'alarm',	'removal',	'emergency-preparedness',	'severe-weather',	'blocking',	'water-purification',	'asbestos',	'lock',	'earthquake' ,	'storm-door' ,	'shutters',	'pet-proofing',	'house-wrap', 	'hurricane-panels',	'precautions',	'vapor-barrier',	'pet-proofing', 'planning',	'moisture','waterproofing' ,	'health-and-safety ',	'cover' ,	'sheathing' ,	'protection',	'rust-proofing',	'rust' ,	'smoke-detectors' ,	'stain-removal' ,	'rust-removal' ,	'water-treatment' ,	'locks' ],
      'walls-drywallls' : ['load-bearing', '	damp-proof-course',	'drywall',	'render',	'rope-knots',	'hanging',	'mount',	'retaining-wall',	'drywall-anchor', 'patching-drywall',	'access-panel',	'taping',	'mudding', 'drywall-mud', 'wallpaper',	'mounting', 'load ' ] ,
      'insulation' : ['spray-foam',	'air-leaks',	'u-value','	winterizing',	'radiant-barrier',	'noise',	'sound-deadening', 'sounds',	'noise-reduction,'	'sound-proofing',	'air-sealing', 'sealing', 'seal','caulk', 'caulking','fiberglass', 'winter',	'acoustic', 'r-value',	'basement-insulation'	] }

# %%
d = {v_i: k for k, v in dict.items() for v_i in v}
df['cat1'] = df['cat1'].map(d).fillna(df['cat1'])
df['cat2'] = df['cat2'].map(d).fillna(df['cat2'])
df['cat3'] = df['cat3'].map(d).fillna(df['cat3'])
df['cat4'] = df['cat4'].map(d).fillna(df['cat4'])
df['cat5'] = df['cat5'].map(d).fillna(df['cat5'])

df.head(5)
# Out:
#                                             question  ...  cat5
# 0  I have a Champion 120V generator, I want to us...  ...  None
# 1  Can I run conduit containing 120V wires inside...  ...  None
# 2  30V on 120 circuit - swapped dishwashers and c...  ...  None
# 3                 How much 120 from 240 is too much?  ...  None
# 4  Is it possible to wire a 240v outlet so that a...  ...  None
#
# [5 rows x 7 columns]

# %%
df['categories'] = df[['cat1', 'cat2', 'cat3', 'cat4', 'cat5']].apply(lambda x: ', '.join(x[x.notnull()]), axis = 1)

# %%
df.head()
# Out:
#                                             question  ...                                      categories
# 0  I have a Champion 120V generator, I want to us...  ...                                      electrical
# 1  Can I run conduit containing 120V wires inside...  ...                  wiring, electrical, electrical
# 2  30V on 120 circuit - swapped dishwashers and c...  ...      electrical, wiring, electrical, electrical
# 3                 How much 120 from 240 is too much?  ...        wiring, exterior-maintenance, electrical
# 4  Is it possible to wire a 240v outlet so that a...  ...  electrical, electrical, electrical, electrical
#
# [5 rows x 8 columns]

# %%
df.drop(df.columns[[2, 3, 4, 5, 6]], axis = 1, inplace = True)
df.head()
# Out:
#                                             question  ...                                      categories
# 0  I have a Champion 120V generator, I want to us...  ...                                      electrical
# 1  Can I run conduit containing 120V wires inside...  ...                  wiring, electrical, electrical
# 2  30V on 120 circuit - swapped dishwashers and c...  ...      electrical, wiring, electrical, electrical
# 3                 How much 120 from 240 is too much?  ...        wiring, exterior-maintenance, electrical
# 4  Is it possible to wire a 240v outlet so that a...  ...  electrical, electrical, electrical, electrical
#
# [5 rows x 3 columns]

# %%
def remove_dup(strng):
    '''
     Input a string and split them 
    '''
    return ', '.join(list(dict.fromkeys(strng.split(', '))))


df['categories'] = df['categories'].apply(lambda x: remove_dup(x))

# %%
df.head()

# %%
df.drop(df[df['categories'] == 'electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'materials'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'lighting'].index, inplace=True)
df.drop(df[df['categories'] == 'hardware-tools'].index, inplace=True)
df.drop(df[df['categories'] == 'appliances'].index, inplace=True)

# %%
df.head(30)
# Out:
#                                               context  ...                                   categories
# 1   I was wondering if I could run 120v wires insi...  ...                           wiring, electrical
# 2   Situation: replaced dishwasher. Turned off the...  ...                           electrical, wiring
# 3   I'm running a double circuit breaker from the ...  ...     wiring, exterior-maintenance, electrical
# 5   I am planning on adding a server to one of the...  ...                           electrical, wiring
# 7   I have a multi wire branch circuit using two 2...  ...                           electrical, wiring
# 8   This cabin is located in the United States, an...  ...                           electrical, wiring
# 9   I have a 240 volt dryer currently, and I want ...  ...                  appliances, gas, electrical
# 13  I am having my main circuit breaker panel repl...  ...                      electrical, wiring, usa
# 15  The breaker panel is on the outside wall, righ...  ...                           electrical, garage
# 19  I found some similar questions but given possi...  ...                           electrical, wiring
# 21  This is how my subpanel looks like. I am looki...  ...                             hvac, electrical
# 22  I have a two pole breaker with three black wir...  ...                           wiring, electrical
# 25  I purchased a 220 V outlet and didn't realize ...  ...                           electrical, wiring
# 26  The oven in question states 40A with 120/240 v...  ...                           electrical, wiring
# 30  We are living on an island where the electrica...  ...                       electrical, appliances
# 31  My garage has very limited power with only one...  ...           wiring, electrical, hardware-tools
# 33  I would like to wall-mount my TV and have the ...  ...                       electrical, appliances
# 34  My electrician wired a single bulb light fixtu...  ...                           electrical, wiring
# 35  I recently moved into an apartment with a 3-pr...  ...                       electrical, appliances
# 36  We currently have 240 high bay metal halide li...  ...                           electrical, wiring
# 37  So I have a ventless dryer, and it's a relativ...  ...                       electrical, appliances
# 38  From a double pole 20-amp breaker, I ran 12/3 ...  ...                           electrical, wiring
# 39  I want to replace my electric water heater wit...  ...                       electrical, appliances
# 43  I'm running 10-3 Romex for a 240v electric dry...  ...             appliances, plumbing, electrical
# 46  The dryer electric driagram identifies  a RED ...  ...                       appliances, electrical
# 47  Will the following wiring diagram work? This 2...  ...                           electrical, wiring
# 48  I have a stackable washer dryer combo with one...  ...                       appliances, electrical
# 49  I recently added a box to install a ceiling fa...  ...                           electrical, wiring
# 51  I want to have two switches (preferably in the...  ...                         electrical, lighting
# 52  I am considering a small 1kW solar system (4x ...  ...  electrical, energy-efficiency, solar-panels
#
# [30 rows x 3 columns]

# %%
df.drop(df[df['categories'] == 'electrical, wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, appliances'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, safety'].index, inplace=True)

df.drop(df[df['categories'] == 'electrical, lighting'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, hardware-tools'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, interior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, insulation'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, repair'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, walls'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, wood'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, doors'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, kitchen'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, basement'].index, inplace=True)

df.drop(df[df['categories'] == 'plumbing, electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, appliances'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, safety'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, bathroom'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, lighting'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, hardware-tools'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, interior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing, insulation'].index, inplace=True)

df.drop(df[df['categories'] == 'wiring, electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring, hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring, exterior-maintenance'].index, inplace=True)

# %%
df.drop(df[df['categories'] == 'materials, electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, appliances'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, safety'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, bathroom'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, lighting'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, hardware-tools'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, interior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'materials, insulation'].index, inplace=True)

df.drop(df[df['categories'] == 'hvac, electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac, wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac, exterior-maintenance'].index, inplace=True)

df.drop(df[df['categories'] == 'exterior-maintenance, electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance, wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance, hvac'].index, inplace=True)

df.drop(df[df['categories'] == 'appliances, electrical'].index, inplace=True)
df.head()
# Out:
#                                               context  ...                                categories
# 3   I'm running a double circuit breaker from the ...  ...  wiring, exterior-maintenance, electrical
# 9   I have a 240 volt dryer currently, and I want ...  ...               appliances, gas, electrical
# 13  I am having my main circuit breaker panel repl...  ...                   electrical, wiring, usa
# 15  The breaker panel is on the outside wall, righ...  ...                        electrical, garage
# 31  My garage has very limited power with only one...  ...        wiring, electrical, hardware-tools
#
# [5 rows x 3 columns]

# %%
df.to_csv(r'/content/drive/MyDrive/Dataset/Trial_dataset.csv', index = True)

# %% [markdown]
# **Start from here**

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/Trial_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  ...                                categories
# 0           0  ...                                electrical
# 1           1  ...                        wiring, electrical
# 2           2  ...                        electrical, wiring
# 3           3  ...  wiring, exterior-maintenance, electrical
# 4           4  ...                                electrical
#
# [5 rows x 4 columns]

# %%
df.drop(df.columns[[ 0, 2 ]], axis = 1, inplace = True)
df.head()
# Out:
#                                             question                                categories
# 0  I have a Champion 120V generator, I want to us...                                electrical
# 1  Can I run conduit containing 120V wires inside...                        wiring, electrical
# 2  30V on 120 circuit - swapped dishwashers and c...                        electrical, wiring
# 3                 How much 120 from 240 is too much?  wiring, exterior-maintenance, electrical
# 4  Is it possible to wire a 240v outlet so that a...                                electrical

# %%
df.shape
# Out:
# (56431, 2)

# %%
df['categories'] = df['categories'].astype('str')

# %%
df_new = pd.DataFrame(df.categories.str.split(',').tolist(), index=df.question).stack()
df_new = df_new.reset_index([0, 'question'])
df_new.columns = ['context', 'categories']

# %%
df_new.head()
# Out:
#                                              context   categories
# 0  I have a Champion 120V generator, I want to us...   electrical
# 1  Can I run conduit containing 120V wires inside...       wiring
# 2  Can I run conduit containing 120V wires inside...   electrical
# 3  30V on 120 circuit - swapped dishwashers and c...   electrical
# 4  30V on 120 circuit - swapped dishwashers and c...       wiring

# %%
df_new['categories'] = df_new['categories'].str.replace(" ", "")
df_new.head()
# Out:
#                                              context  categories
# 0  I have a Champion 120V generator, I want to us...  electrical
# 1  Can I run conduit containing 120V wires inside...      wiring
# 2  Can I run conduit containing 120V wires inside...  electrical
# 3  30V on 120 circuit - swapped dishwashers and c...  electrical
# 4  30V on 120 circuit - swapped dishwashers and c...      wiring

# %%
## for i, name in enumerate(df_new['categories'].value_counts().index.tolist()):
    ## print('Name :', name)
    ## print('Counts :', df_new['categories'].value_counts()[i])

# %%
c = df_new['categories'].value_counts()
c.head(13)
# Out:
# electrical              15264
# plumbing                 8200
# materials                5604
# wiring                   5258
# hvac                     5257
# exterior-maintenance     4733
# lighting                 3642
# appliances               3488
# hardware-tools           3294
# safety                   2786
# walls-drywallls          2509
# interior-maintenance     2491
# insulation               2191
# Name: categories, dtype: int64

# %%
x = (df_new[df_new['categories'] == 'electrical'])
x.head()
# Out:
#                                              context  categories
# 0  I have a Champion 120V generator, I want to us...  electrical
# 2  Can I run conduit containing 120V wires inside...  electrical
# 3  30V on 120 circuit - swapped dishwashers and c...  electrical
# 7                 How much 120 from 240 is too much?  electrical
# 8  Is it possible to wire a 240v outlet so that a...  electrical

# %%
x1 = (df_new[df_new['categories'] == 'plumbing'])
x1.head()

x2 = (df_new[df_new['categories'] == 'materials'])
x2.head()

x3 = (df_new[df_new['categories'] == 'wiring'])
x3.head()

x4 = (df_new[df_new['categories'] == 'hvac'])
x4.head()

x5 = (df_new[df_new['categories'] == 'exterior-maintenance'])
x5.head()

x6 = (df_new[df_new['categories'] == 'lighting'])
x6.head()

x7 = (df_new[df_new['categories'] == 'hardware-tools'])
x7.head()

x8 = (df_new[df_new['categories'] == 'appliances'])
x8.head()

x10 = (df_new[df_new['categories'] == 'safety'])
x10.head()

x11 = (df_new[df_new['categories'] == 'walls-drywallls'])
x11.head()

x12 = (df_new[df_new['categories'] == 'interior-maintenance'])
x12.head()

x13 = (df_new[df_new['categories'] == 'insulation'])
x13.head()
# Out:
#                                                context  categories
# 693                Cellulose ceiling tiles (asbestos?)  insulation
# 695    How should I stick acoustic foams on the walls?  insulation
# 698  Painting acoustic drywall with large perforations  insulation
# 701            Mounting Acoustic Foam in a rented flat  insulation
# 703  Using acoustic foam between two windows to blo...  insulation

# %%
frames = [x, x1, x2, x3, x4, x5, x6, x7, x8, x10, x11, x12, x13]
result = pd.concat(frames)
result.shape
# Out:
# (64717, 2)

# %%
result.head()
# Out:
#                                              context  categories
# 0  I have a Champion 120V generator, I want to us...  electrical
# 2  Can I run conduit containing 120V wires inside...  electrical
# 3  30V on 120 circuit - swapped dishwashers and c...  electrical
# 7                 How much 120 from 240 is too much?  electrical
# 8  Is it possible to wire a 240v outlet so that a...  electrical

# %%
count = result['categories'].value_counts()

count.head(60)
# Out:
# electrical              15264
# plumbing                 8200
# materials                5604
# wiring                   5258
# hvac                     5257
# exterior-maintenance     4733
# lighting                 3642
# appliances               3488
# hardware-tools           3294
# safety                   2786
# walls-drywallls          2509
# interior-maintenance     2491
# insulation               2191
# Name: categories, dtype: int64

# %%
df = result['categories'].groupby([result.context]).apply(list).reset_index()

# %%
df.head()
# Out:
#                                              context              categories
# 0              "3-in-1" kits for maytag refrigerator            [appliances]
# 1  "Attic stairs" equivelent in an attic "hatch" ...  [interior-maintenance]
# 2  "Axle cap": what is it called and how to remov...        [hardware-tools]
# 3                                "Bendy" screwdriver        [hardware-tools]
# 4  "Built-in corrosion inhibition" - Does it work...        [hardware-tools]

# %%
df = df.replace('\n','', regex=True)
df.head()
# Out:
#                                              context              categories
# 0              "3-in-1" kits for maytag refrigerator            [appliances]
# 1  "Attic stairs" equivelent in an attic "hatch" ...  [interior-maintenance]
# 2  "Axle cap": what is it called and how to remov...        [hardware-tools]
# 3                                "Bendy" screwdriver        [hardware-tools]
# 4  "Built-in corrosion inhibition" - Does it work...        [hardware-tools]

# %%
df['categories'] = df['categories'].astype('str')

# %%
df['categories'] = df['categories'].str.replace("[\[\]\"']", "")

# %%
df.head()
# Out:
#                                              context            categories
# 0              "3-in-1" kits for maytag refrigerator            appliances
# 1  "Attic stairs" equivelent in an attic "hatch" ...  interior-maintenance
# 2  "Axle cap": what is it called and how to remov...        hardware-tools
# 3                                "Bendy" screwdriver        hardware-tools
# 4  "Built-in corrosion inhibition" - Does it work...        hardware-tools

# %%
df.drop(df[df['categories'] == 'electrical'].index, inplace=True)
df.drop(df[df['categories'] == 'plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'wiring'].index, inplace=True)
df.drop(df[df['categories'] == 'materials'].index, inplace=True)
df.drop(df[df['categories'] == 'exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, plumbing'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, hvac'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, materials'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, exterior-maintenance'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, appliances'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, safety'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, lighting'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, hardware-tools'].index, inplace=True)
df.drop(df[df['categories'] == 'electrical, interior-maintenance'].index, inplace=True)

# %%
df.shape
# Out:
# (21218, 2)

# %%
df.head()
# Out:
#                                              context            categories
# 0              "3-in-1" kits for maytag refrigerator            appliances
# 1  "Attic stairs" equivelent in an attic "hatch" ...  interior-maintenance
# 2  "Axle cap": what is it called and how to remov...        hardware-tools
# 3                                "Bendy" screwdriver        hardware-tools
# 4  "Built-in corrosion inhibition" - Does it work...        hardware-tools

# %%
df = pd.DataFrame(df.categories.str.split(',').tolist(), index=df.context).stack()
df = df.reset_index([0, 'context'])
df.columns = ['context', 'categories']

# %%
df.head()
# Out:
#                                              context            categories
# 0              "3-in-1" kits for maytag refrigerator            appliances
# 1  "Attic stairs" equivelent in an attic "hatch" ...  interior-maintenance
# 2  "Axle cap": what is it called and how to remov...        hardware-tools
# 3                                "Bendy" screwdriver        hardware-tools
# 4  "Built-in corrosion inhibition" - Does it work...        hardware-tools

# %%
df['categories'] = df['categories'].str.replace(" ", "")
df.head()
# Out:
#                                              context            categories
# 0              "3-in-1" kits for maytag refrigerator            appliances
# 1  "Attic stairs" equivelent in an attic "hatch" ...  interior-maintenance
# 2  "Axle cap": what is it called and how to remov...        hardware-tools
# 3                                "Bendy" screwdriver        hardware-tools
# 4  "Built-in corrosion inhibition" - Does it work...        hardware-tools

# %%
c = df['categories'].value_counts()
c.head(13)
# Out:
# electrical              4410
# wiring                  4322
# hardware-tools          3129
# appliances              3038
# materials               2969
# exterior-maintenance    2573
# safety                  2556
# plumbing                2523
# walls-drywallls         2509
# interior-maintenance    2431
# lighting                2381
# insulation              2191
# hvac                    2155
# Name: categories, dtype: int64

# %%
df = df['categories'].groupby([df.context]).apply(list).reset_index()

# %%
df.shape
# Out:
# (21218, 2)

# %%
df.head()
# Out:
#                                              context              categories
# 0              "3-in-1" kits for maytag refrigerator            [appliances]
# 1  "Attic stairs" equivelent in an attic "hatch" ...  [interior-maintenance]
# 2  "Axle cap": what is it called and how to remov...        [hardware-tools]
# 3                                "Bendy" screwdriver        [hardware-tools]
# 4  "Built-in corrosion inhibition" - Does it work...        [hardware-tools]

# %%
df["id"] = df.index + 1
df = df[['id','context','categories']]
df.head()
# Out:
#    id  ...              categories
# 0   1  ...            [appliances]
# 1   2  ...  [interior-maintenance]
# 2   3  ...        [hardware-tools]
# 3   4  ...        [hardware-tools]
# 4   5  ...        [hardware-tools]
#
# [5 rows x 3 columns]

# %%
df.to_csv(r'/content/drive/MyDrive/Dataset/HMDataset.csv', index = False)
